# %% [markdown]
# ## Introducción
#
# En el siguiente enlace se puede ver un esquema de las cuentas utilizadas en el SEC-10, y que son las contempladas en el temario para las oposiciones al cuerpo de DEE del INE
#
#
# <a href="sucesiónCuentas.html" target="_blank"> Ver sucesión de cuentas</a>
#
# Igualmente se pueden consultar las cuentas del Resto del Mundo en este enlace:
#
# <a href="CuentasRestoMundo.html" target="_blank"> Ver sucesión de cuentas del Resto del Mundo</a>
